# %% [markdown]
# ### Import Libraries

# %%
import nibabel
import ants
import numpy as np
import pandas as pd
import os
from math import ceil
import multiprocessing as mp
import re
import matplotlib.pyplot as plt
import glob

from nilearn.image import load_img, smooth_img, resample_img, get_data
from nilearn.plotting import show, view_img, plot_img

# %% [markdown]
# ### Define Paths

# %%
research_dir = '/media/jraad/Data1/school/research/'
data_dir = os.path.join(research_dir, 'data')
dhcp_dir = os.path.join(data_dir, 'dHCP')
img_dir = os.path.join(dhcp_dir, 'samples')
dhcp_stripped = os.path.join(dhcp_dir, 'stripped')
dhcp_registered = os.path.join(dhcp_dir, 'registered')
dhcp_self_registered = os.path.join(dhcp_dir, 'self_registered')
dhcp_norm = os.path.join(dhcp_dir, 'normalized')
dhcp_self_norm = os.path.join(dhcp_dir, 'self_normalized')
dhcp_standardized = os.path.join(dhcp_dir, 'standardized')

dhcp_remote = '/media/jraad/jadadactyl/dhcp_anat_pipeline'

chm_dir = os.path.join(data_dir, 'chm')
neonates_dir = os.path.join(chm_dir, 'Neonates_T2')
normal_dir = os.path.join(neonates_dir, 'Normal')
abnormal_dir = os.path.join(neonates_dir, 'Abnormal')
death_dir = os.path.join(neonates_dir, 'Death')
chm_stripped = os.path.join(chm_dir, 'Neonates_T2_stripped')
chm_registered = os.path.join(chm_dir, 'registered')
chm_norm = os.path.join(chm_dir, 'normalized')

# %% [markdown]
# ### Define Uniform Distribution

# %%
uniform = np.random.uniform(size=500)
np.save(os.path.join(data_dir, 'uniform.npy'), uniform)

# %% [markdown]
# ### Read Uniform Distribution

# %%
uniform = np.load(os.path.join(data_dir, 'uniform.npy'))

# %% [markdown]
# ### Define Histogram Normalization

# %%
def hist_match(source, template):
    """
    Adjust the pixel values of a grayscale image such that its histogram
    matches that of a target image.
    Code adapted from
    http://stackoverflow.com/questions/32655686/histogram-matching-of-two-images-in-python-2-x
    Arguments:
    -----------
        source: np.ndarray
            Image to transform; the histogram is computed over the flattened
            array
        template: np.ndarray
            Template image; can have different dimensions to source
    Returns:
    -----------
        matched: np.ndarray
            The transformed output image
    """

    oldshape = source.shape
    source = source.ravel()
    template = template.ravel()

    # get the set of unique pixel values and their corresponding indices and
    # counts
    s_values, bin_idx, s_counts = np.unique(source, return_inverse=True,
                                            return_counts=True)
    t_values, t_counts = np.unique(template, return_counts=True)

    # take the cumsum of the counts and normalize by the number of pixels to
    # get the empirical cumulative distribution functions for the source and
    # template images (maps pixel value --> quantile)
    s_quantiles = np.cumsum(s_counts).astype(np.float64)
#     s_quantiles /= s_quantiles[-1]
    s_min = min(s_quantiles)
    s_max = max(s_quantiles)
    s_quantiles = (s_quantiles - s_min) / (s_max - s_min)
    
    t_quantiles = np.cumsum(t_counts).astype(np.float64)
    t_quantiles /= t_quantiles[-1]

    # interpolate linearly to find the pixel values in the template image
    # that correspond most closely to the quantiles in the source image
    interp_t_values = np.interp(s_quantiles, t_quantiles, t_values)

    return interp_t_values[bin_idx].reshape(oldshape)

# %% [markdown]
# ### Define Skull Stripping

# %%
def strip_image(input_path, output_path):
    stream = os.popen(f'bet2 {input_path} {output_path} -f 0.2')

def process_folder_dhcp(path, output):
    for file in os.listdir(path):
        img_path = os.path.join(path, file)
        out_path = os.path.join(output, file)
        strip_image(img_path, out_path)
    
def process_folder_chm(path, output, tag):
    for folder_name in os.listdir(path):
        img_path = os.path.join(path, folder_name, 'T2_anonymous.nii')
        out_path = os.path.join(output, f'{tag}_{folder_name}.nii')
        strip_image(img_path, out_path)

# %% [markdown]
# ### Read dHCP Metadata

# %%
listing = glob.glob(os.path.join(dhcp_remote, 'sub-*'))
counter = 0
for folder in listing:
    subject = os.path.basename(folder)
    if counter == 0:
        session = pd.read_csv(os.path.join(folder,f'{subject}_sessions.tsv'), sep='\t')
        session['subject'] = subject
        session_id = max(session.session_id)
        sessions = session[session.session_id == session_id]
        counter += 1
    else:
        session = pd.read_csv(os.path.join(folder,f'{subject}_sessions.tsv'), sep='\t')
        session.subject = subject
        session['subject'] = subject
        session_id = max(session.session_id)
        sessions = sessions.append(session[session.session_id == session_id])

# %% [markdown]
# ### Strip dHCP Data

# %%
file_list = os.listdir(img_dir)
file_list = sorted(file_list)

for file in file_list:
    subject = file[0:15]
    subject_info = sessions[sessions.subject == subject]
    subject_out = os.path.join(dhcp_stripped, f'{subject}_{subject_info.radiology_score.values[0]}.nii.gz')
    strip_image(os.path.join(img_dir, file), subject_out)

# %% [markdown]
# ### Strip CHM Data

# %%
process_folder(normal_dir, chm_stripped, 'normal')
process_folder(abnormal_dir, chm_stripped, 'abnormal')
process_folder(death_dir, chm_stripped, 'death')

# %% [markdown]
# ### Clean CHM Data

# %%
# %%time

x, y, z = (256, 256, 32)

imgs = []
counter = 0
for file in os.listdir(chm_stripped):
    file_path = os.path.join(chm_stripped, file)
    img = ants.image_read(file_path)
    img = ants.resample_image(img, (x, y, z), True, 1)
    img = ants.n3_bias_field_correction(img)
    if counter == 0:
        ants.image_write(img, os.path.join(chm_registered, file))
        ref_img = img
    else:
        img = ants.registration(fixed=ref_img, moving=img, type_of_transform='AffineFast')
        ants.image_write(img['warpedmovout'], os.path.join(chm_registered, file))
    counter += 1
# Out:
# CPU times: user 3min 45s, sys: 5.92 s, total: 3min 51s
# Wall time: 32.6 s

# %% [markdown]
# ### Clean dHCP Data

# %%
# %%time

samples = []

counter = 0
z_dhcp = 256

file_list = os.listdir(dhcp_stripped)
file_list = sorted(file_list)

for file in file_list:
    print(f"processing image {counter}, {file}")
    file_path = os.path.join(dhcp_stripped, file)
    img = ants.image_read(file_path)    
    img = ants.n3_bias_field_correction(img)
    img = ants.resample_image(img, (x, y, z_dhcp), True, 1)
    for i in range(0, 8):
        sub_path = os.path.join(dhcp_registered, f"set{i}_{file}")
        img_sub = img.numpy()[:,:,range(i,z_dhcp,8)]
        img_sub = ref_img.new_image_like(img_sub)
        img_sub = ants.registration(fixed=ref_img, moving=img_sub, type_of_transform='AffineFast')
        ants.image_write(img_sub['warpedmovout'], sub_path)
    counter += 1
# Out:
# processing image 0, sub-CC00058XX09_1.nii.gz
# processing image 1, sub-CC00060XX03_2.nii.gz
# processing image 2, sub-CC00062XX05_1.nii.gz
# processing image 3, sub-CC00063AN06_1.nii.gz
# processing image 4, sub-CC00065XX08_2.nii.gz
# processing image 5, sub-CC00066XX09_4.nii.gz
# processing image 6, sub-CC00067XX10_1.nii.gz
# processing image 7, sub-CC00068XX11_1.nii.gz
# processing image 8, sub-CC00069XX12_2.nii.gz
# processing image 9, sub-CC00070XX05_3.nii.gz
# processing image 10, sub-CC00071XX06_1.nii.gz
# processing image 11, sub-CC00072XX07_2.nii.gz
# processing image 12, sub-CC00073XX08_1.nii.gz
# processing image 13, sub-CC00074XX09_1.nii.gz
# processing image 14, sub-CC00075XX10_1.nii.gz
# processing image 15, sub-CC00078XX13_2.nii.gz
# processing image 16, sub-CC00079XX14_1.nii.gz
# processing image 17, sub-CC00080XX07_1.nii.gz
# processing image 18, sub-CC00082XX09_1.nii.gz
# processing image 19, sub-CC00083XX10_1.nii.gz
# processing image 20, sub-CC00084XX11_1.nii.gz
# processing image 21, sub-CC00086XX13_2.nii.gz
# processing image 22, sub-CC00087AN14_5.nii.gz
# processing image 23, sub-CC00087BN14_2.nii.gz
# processing image 24, sub-CC00088XX15_1.nii.gz
# processing image 25, sub-CC00089XX16_1.nii.gz
# processing image 26, sub-CC00091XX10_2.nii.gz
# processing image 27, sub-CC00094AN13_2.nii.gz
# processing image 28, sub-CC00094BN13_2.nii.gz
# processing image 29, sub-CC00096XX15_1.nii.gz
# processing image 30, sub-CC00097XX16_1.nii.gz
# processing image 31, sub-CC00098BN17_1.nii.gz
# processing image 32, sub-CC00099AN18_Q.nii.gz
# processing image 33, sub-CC00099BN18_1.nii.gz
# processing image 34, sub-CC00100XX01_1.nii.gz
# processing image 35, sub-CC00101XX02_1.nii.gz
# processing image 36, sub-CC00102XX03_1.nii.gz
# processing image 37, sub-CC00103XX04_5.nii.gz
# processing image 38, sub-CC00104XX05_1.nii.gz
# processing image 39, sub-CC00106XX07_1.nii.gz
# processing image 40, sub-CC00107XX08_1.nii.gz
# processing image 41, sub-CC00108XX09_1.nii.gz
# processing image 42, sub-CC00109XX10_Q.nii.gz
# processing image 43, sub-CC00110XX03_1.nii.gz
# processing image 44, sub-CC00111XX04_2.nii.gz
# processing image 45, sub-CC00113XX06_1.nii.gz
# processing image 46, sub-CC00114XX07_2.nii.gz
# processing image 47, sub-CC00115XX08_2.nii.gz
# processing image 48, sub-CC00116XX09_3.nii.gz
# processing image 49, sub-CC00117XX10_1.nii.gz
# processing image 50, sub-CC00118XX11_1.nii.gz
# processing image 51, sub-CC00119XX12_2.nii.gz
# processing image 52, sub-CC00120XX05_1.nii.gz
# processing image 53, sub-CC00121XX06_4.nii.gz
# processing image 54, sub-CC00122XX07_1.nii.gz
# processing image 55, sub-CC00124XX09_1.nii.gz
# processing image 56, sub-CC00126XX11_1.nii.gz
# processing image 57, sub-CC00127XX12_1.nii.gz
# processing image 58, sub-CC00129AN14_1.nii.gz
# processing image 59, sub-CC00129BN14_3.nii.gz
# processing image 60, sub-CC00130XX07_3.nii.gz
# processing image 61, sub-CC00131XX08_1.nii.gz
# processing image 62, sub-CC00132XX09_1.nii.gz
# processing image 63, sub-CC00134XX11_1.nii.gz
# processing image 64, sub-CC00135AN12_3.nii.gz
# processing image 65, sub-CC00135BN12_3.nii.gz
# processing image 66, sub-CC00136AN13_1.nii.gz
# processing image 67, sub-CC00136BN13_1.nii.gz
# processing image 68, sub-CC00138XX15_1.nii.gz
# processing image 69, sub-CC00143AN12_1.nii.gz
# processing image 70, sub-CC00143BN12_2.nii.gz
# processing image 71, sub-CC00144XX13_Q3.nii.gz
# processing image 72, sub-CC00145XX14_1.nii.gz
# processing image 73, sub-CC00146XX15_1.nii.gz
# processing image 74, sub-CC00147XX16_1.nii.gz
# processing image 75, sub-CC00149XX18_1.nii.gz
# processing image 76, sub-CC00150AN02_1.nii.gz
# processing image 77, sub-CC00150BN02_1.nii.gz
# processing image 78, sub-CC00152AN04_4.nii.gz
# processing image 79, sub-CC00153XX05_1.nii.gz
# processing image 80, sub-CC00154XX06_2.nii.gz
# processing image 81, sub-CC00156XX08_2.nii.gz
# processing image 82, sub-CC00157XX09_1.nii.gz
# processing image 83, sub-CC00158XX10_2.nii.gz
# processing image 84, sub-CC00160XX04_1.nii.gz
# processing image 85, sub-CC00161XX05_1.nii.gz
# processing image 86, sub-CC00162XX06_1.nii.gz
# processing image 87, sub-CC00163XX07_1.nii.gz
# processing image 88, sub-CC00164XX08_1.nii.gz
# processing image 89, sub-CC00165XX09_1.nii.gz
# processing image 90, sub-CC00167XX11_2.nii.gz
# processing image 91, sub-CC00168XX12_1.nii.gz
# processing image 92, sub-CC00170XX06_1.nii.gz
# processing image 93, sub-CC00171XX07_2.nii.gz
# processing image 94, sub-CC00172AN08_1.nii.gz
# processing image 95, sub-CC00172BN08_1.nii.gz
# processing image 96, sub-CC00174XX10_2.nii.gz
# processing image 97, sub-CC00176XX12_1.nii.gz
# processing image 98, sub-CC00177XX13_1.nii.gz
# processing image 99, sub-CC00178XX14_1.nii.gz
# processing image 100, sub-CC00179XX15_1.nii.gz
# processing image 101, sub-CC00180XX08_1.nii.gz
# processing image 102, sub-CC00181XX09_1.nii.gz
# processing image 103, sub-CC00182XX10_1.nii.gz
# processing image 104, sub-CC00183XX11_1.nii.gz
# processing image 105, sub-CC00184XX12_1.nii.gz
# processing image 106, sub-CC00185XX13_2.nii.gz
# processing image 107, sub-CC00186AN14_3.nii.gz
# processing image 108, sub-CC00186BN14_3.nii.gz
# processing image 109, sub-CC00187XX15_1.nii.gz
# processing image 110, sub-CC00188XX16_1.nii.gz
# processing image 111, sub-CC00189XX17_1.nii.gz
# processing image 112, sub-CC00191XX11_2.nii.gz
# processing image 113, sub-CC00192AN12_3.nii.gz
# processing image 114, sub-CC00193XX13_1.nii.gz
# processing image 115, sub-CC00194XX14_5.nii.gz
# processing image 116, sub-CC00195XX15_1.nii.gz
# processing image 117, sub-CC00196XX16_1.nii.gz
# processing image 118, sub-CC00197XX17_3.nii.gz
# processing image 119, sub-CC00198XX18_1.nii.gz
# processing image 120, sub-CC00199XX19_3.nii.gz
# processing image 121, sub-CC00200XX02_1.nii.gz
# processing image 122, sub-CC00201XX03_1.nii.gz
# processing image 123, sub-CC00202XX04_2.nii.gz
# processing image 124, sub-CC00203XX05_2.nii.gz
# processing image 125, sub-CC00204XX06_1.nii.gz
# processing image 126, sub-CC00205XX07_1.nii.gz
# processing image 127, sub-CC00206XX08_1.nii.gz
# processing image 128, sub-CC00207XX09_1.nii.gz
# processing image 129, sub-CC00209XX11_1.nii.gz
# processing image 130, sub-CC00216AN10_2.nii.gz
# processing image 131, sub-CC00216BN10_2.nii.gz
# processing image 132, sub-CC00217XX11_1.nii.gz
# processing image 133, sub-CC00218AN12_5.nii.gz
# processing image 134, sub-CC00218BN12_1.nii.gz
# processing image 135, sub-CC00219XX13_3.nii.gz
# processing image 136, sub-CC00221XX07_4.nii.gz
# processing image 137, sub-CC00223XX09_1.nii.gz
# processing image 138, sub-CC00226XX12_2.nii.gz
# processing image 139, sub-CC00227XX13_1.nii.gz
# processing image 140, sub-CC00231XX09_5.nii.gz
# processing image 141, sub-CC00232XX10_1.nii.gz
# processing image 142, sub-CC00233XX11_1.nii.gz
# processing image 143, sub-CC00236XX14_2.nii.gz
# processing image 144, sub-CC00237XX15_2.nii.gz
# processing image 145, sub-CC00238AN16_2.nii.gz
# processing image 146, sub-CC00238BN16_1.nii.gz
# processing image 147, sub-CC00244XX14_3.nii.gz
# processing image 148, sub-CC00245AN15_1.nii.gz
# processing image 149, sub-CC00245BN15_1.nii.gz
# processing image 150, sub-CC00247XX17_1.nii.gz
# processing image 151, sub-CC00248XX18_5.nii.gz
# processing image 152, sub-CC00250XX03_1.nii.gz
# processing image 153, sub-CC00251XX04_1.nii.gz
# processing image 154, sub-CC00252XX05_2.nii.gz
# processing image 155, sub-CC00254XX07_1.nii.gz
# processing image 156, sub-CC00255XX08_5.nii.gz
# processing image 157, sub-CC00257XX10_1.nii.gz
# processing image 158, sub-CC00258XX11_1.nii.gz
# processing image 159, sub-CC00260XX05_2.nii.gz
# processing image 160, sub-CC00261XX06_1.nii.gz
# processing image 161, sub-CC00265XX10_2.nii.gz
# processing image 162, sub-CC00267XX12_2.nii.gz
# processing image 163, sub-CC00268XX13_1.nii.gz
# processing image 164, sub-CC00269XX14_2.nii.gz
# processing image 165, sub-CC00270XX07_3.nii.gz
# processing image 166, sub-CC00271XX08_2.nii.gz
# processing image 167, sub-CC00272XX09_1.nii.gz
# processing image 168, sub-CC00275XX12_1.nii.gz
# processing image 169, sub-CC00281AN10_1.nii.gz
# processing image 170, sub-CC00284AN13_2.nii.gz
# processing image 171, sub-CC00284BN13_2.nii.gz
# processing image 172, sub-CC00286XX15_1.nii.gz
# processing image 173, sub-CC00289XX18_2.nii.gz
# processing image 174, sub-CC00290XX11_1.nii.gz
# processing image 175, sub-CC00292XX13_2.nii.gz
# processing image 176, sub-CC00293AN14_2.nii.gz
# processing image 177, sub-CC00293BN14_2.nii.gz
# processing image 178, sub-CC00295XX16_1.nii.gz
# processing image 179, sub-CC00298XX19_2.nii.gz
# processing image 180, sub-CC00299XX20_1.nii.gz
# processing image 181, sub-CC00300XX03_1.nii.gz
# processing image 182, sub-CC00301XX04_5.nii.gz
# processing image 183, sub-CC00302XX05_1.nii.gz
# processing image 184, sub-CC00303XX06_2.nii.gz
# processing image 185, sub-CC00304XX07_1.nii.gz
# processing image 186, sub-CC00305XX08_2.nii.gz
# processing image 187, sub-CC00306XX09_2.nii.gz
# processing image 188, sub-CC00307XX10_2.nii.gz
# processing image 189, sub-CC00308XX11_1.nii.gz
# processing image 190, sub-CC00309BN12_2.nii.gz
# processing image 191, sub-CC00313XX08_1.nii.gz
# processing image 192, sub-CC00314XX09_2.nii.gz
# processing image 193, sub-CC00316XX11_2.nii.gz
# processing image 194, sub-CC00319XX14_1.nii.gz
# processing image 195, sub-CC00320XX07_2.nii.gz
# processing image 196, sub-CC00324XX11_2.nii.gz
# processing image 197, sub-CC00326XX13_1.nii.gz
# processing image 198, sub-CC00329XX16_2.nii.gz
# processing image 199, sub-CC00330XX09_1.nii.gz
# processing image 200, sub-CC00332XX11_1.nii.gz
# processing image 201, sub-CC00334XX13_1.nii.gz
# processing image 202, sub-CC00335XX14_2.nii.gz
# processing image 203, sub-CC00336XX15_2.nii.gz
# processing image 204, sub-CC00337XX16_1.nii.gz
# processing image 205, sub-CC00338AN17_1.nii.gz
# processing image 206, sub-CC00338BN17_1.nii.gz
# processing image 207, sub-CC00339XX18_2.nii.gz
# processing image 208, sub-CC00340XX11_2.nii.gz
# processing image 209, sub-CC00341XX12_3.nii.gz
# processing image 210, sub-CC00342XX13_1.nii.gz
# processing image 211, sub-CC00343XX14_2.nii.gz
# processing image 212, sub-CC00344XX15_1.nii.gz
# processing image 213, sub-CC00346XX17_1.nii.gz
# processing image 214, sub-CC00347XX18_2.nii.gz
# processing image 215, sub-CC00348XX19_1.nii.gz
# processing image 216, sub-CC00349XX20_2.nii.gz
# processing image 217, sub-CC00350XX04_3.nii.gz
# processing image 218, sub-CC00351XX05_1.nii.gz
# processing image 219, sub-CC00352XX06_2.nii.gz
# processing image 220, sub-CC00354XX08_1.nii.gz
# processing image 221, sub-CC00355XX09_2.nii.gz
# processing image 222, sub-CC00356XX10_2.nii.gz
# processing image 223, sub-CC00357XX11_1.nii.gz
# processing image 224, sub-CC00361XX07_1.nii.gz
# processing image 225, sub-CC00362XX08_2.nii.gz
# processing image 226, sub-CC00363XX09_1.nii.gz
# processing image 227, sub-CC00364XX10_2.nii.gz
# processing image 228, sub-CC00366XX12_3.nii.gz
# processing image 229, sub-CC00367XX13_1.nii.gz
# processing image 230, sub-CC00368XX14_1.nii.gz
# processing image 231, sub-CC00370XX08_2.nii.gz
# processing image 232, sub-CC00371XX09_2.nii.gz
# processing image 233, sub-CC00376XX14_1.nii.gz
# processing image 234, sub-CC00377XX15_2.nii.gz
# processing image 235, sub-CC00378XX16_1.nii.gz
# processing image 236, sub-CC00379XX17_4.nii.gz
# processing image 237, sub-CC00380XX10_2.nii.gz
# processing image 238, sub-CC00381XX11_1.nii.gz
# processing image 239, sub-CC00382XX12_1.nii.gz
# processing image 240, sub-CC00383XX13_1.nii.gz
# processing image 241, sub-CC00384XX14_5.nii.gz
# processing image 242, sub-CC00385XX15_1.nii.gz
# processing image 243, sub-CC00388XX18_2.nii.gz
# processing image 244, sub-CC00389XX19_2.nii.gz
# processing image 245, sub-CC00395XX17_5.nii.gz
# processing image 246, sub-CC00397XX19_4.nii.gz
# processing image 247, sub-CC00398XX20_4.nii.gz
# processing image 248, sub-CC00399XX21_3.nii.gz
# processing image 249, sub-CC00400XX04_2.nii.gz
# processing image 250, sub-CC00402XX06_1.nii.gz
# processing image 251, sub-CC00403XX07_2.nii.gz
# processing image 252, sub-CC00405XX09_3.nii.gz
# processing image 253, sub-CC00406XX10_3.nii.gz
# processing image 254, sub-CC00407AN11_3.nii.gz
# processing image 255, sub-CC00407BN11_1.nii.gz
# processing image 256, sub-CC00408XX12_2.nii.gz
# processing image 257, sub-CC00409XX13_2.nii.gz
# processing image 258, sub-CC00410XX06_1.nii.gz
# processing image 259, sub-CC00411XX07_3.nii.gz
# processing image 260, sub-CC00412XX08_2.nii.gz
# processing image 261, sub-CC00413XX09_1.nii.gz
# processing image 262, sub-CC00414XX10_5.nii.gz
# processing image 263, sub-CC00415XX11_1.nii.gz
# processing image 264, sub-CC00416XX12_5.nii.gz
# processing image 265, sub-CC00417XX13_3.nii.gz
# processing image 266, sub-CC00418AN14_3.nii.gz
# processing image 267, sub-CC00418BN14_5.nii.gz
# processing image 268, sub-CC00421AN09_1.nii.gz
# processing image 269, sub-CC00421BN09_1.nii.gz
# processing image 270, sub-CC00422XX10_3.nii.gz
# processing image 271, sub-CC00423XX11_5.nii.gz
# processing image 272, sub-CC00424XX12_2.nii.gz
# processing image 273, sub-CC00428XX16_2.nii.gz
# processing image 274, sub-CC00429XX17_1.nii.gz
# processing image 275, sub-CC00430XX10_1.nii.gz
# processing image 276, sub-CC00431XX11_2.nii.gz
# processing image 277, sub-CC00433XX13_1.nii.gz
# processing image 278, sub-CC00434AN14_3.nii.gz
# processing image 279, sub-CC00438XX18_1.nii.gz
# processing image 280, sub-CC00439XX19_2.nii.gz
# processing image 281, sub-CC00440XX12_2.nii.gz
# processing image 282, sub-CC00441XX13_2.nii.gz
# processing image 283, sub-CC00442XX14_2.nii.gz
# processing image 284, sub-CC00443XX15_2.nii.gz
# processing image 285, sub-CC00444XX16_2.nii.gz
# processing image 286, sub-CC00445XX17_2.nii.gz
# processing image 287, sub-CC00446XX18_2.nii.gz
# processing image 288, sub-CC00447XX19_2.nii.gz
# processing image 289, sub-CC00448XX20_2.nii.gz
# processing image 290, sub-CC00450XX05_2.nii.gz
# processing image 291, sub-CC00451XX06_2.nii.gz
# processing image 292, sub-CC00453XX08_1.nii.gz
# processing image 293, sub-CC00454XX09_5.nii.gz
# processing image 294, sub-CC00455XX10_2.nii.gz
# processing image 295, sub-CC00456XX11_5.nii.gz
# processing image 296, sub-CC00457XX12_2.nii.gz
# processing image 297, sub-CC00458XX13_1.nii.gz
# processing image 298, sub-CC00461XX08_2.nii.gz
# processing image 299, sub-CC00465XX12_2.nii.gz
# processing image 300, sub-CC00466AN13_2.nii.gz
# processing image 301, sub-CC00466BN13_2.nii.gz
# processing image 302, sub-CC00467XX14_2.nii.gz
# processing image 303, sub-CC00468XX15_1.nii.gz
# processing image 304, sub-CC00469XX16_2.nii.gz
# processing image 305, sub-CC00470XX09_2.nii.gz
# processing image 306, sub-CC00472XX11_2.nii.gz
# processing image 307, sub-CC00473XX12_1.nii.gz
# processing image 308, sub-CC00474XX13_2.nii.gz
# processing image 309, sub-CC00476XX15_1.nii.gz
# processing image 310, sub-CC00478XX17_2.nii.gz
# processing image 311, sub-CC00479XX18_1.nii.gz
# processing image 312, sub-CC00480XX11_1.nii.gz
# processing image 313, sub-CC00481XX12_2.nii.gz
# processing image 314, sub-CC00482XX13_2.nii.gz
# processing image 315, sub-CC00483XX14_2.nii.gz
# processing image 316, sub-CC00484XX15_1.nii.gz
# processing image 317, sub-CC00486XX17_2.nii.gz
# processing image 318, sub-CC00489XX20_3.nii.gz
# processing image 319, sub-CC00492AN15_1.nii.gz
# processing image 320, sub-CC00492BN15_2.nii.gz
# processing image 321, sub-CC00497XX20_1.nii.gz
# processing image 322, sub-CC00498XX21_2.nii.gz
# processing image 323, sub-CC00499XX22_2.nii.gz
# processing image 324, sub-CC00500XX05_1.nii.gz
# processing image 325, sub-CC00501XX06_1.nii.gz
# processing image 326, sub-CC00502XX07_2.nii.gz
# processing image 327, sub-CC00504XX09_1.nii.gz
# processing image 328, sub-CC00505XX10_2.nii.gz
# processing image 329, sub-CC00507XX12_1.nii.gz
# processing image 330, sub-CC00508XX13_2.nii.gz
# processing image 331, sub-CC00512XX09_2.nii.gz
# processing image 332, sub-CC00513XX10_5.nii.gz
# processing image 333, sub-CC00514XX11_1.nii.gz
# processing image 334, sub-CC00516XX13_2.nii.gz
# processing image 335, sub-CC00517XX14_3.nii.gz
# processing image 336, sub-CC00518XX15_3.nii.gz
# processing image 337, sub-CC00520XX09_2.nii.gz
# processing image 338, sub-CC00525XX14_2.nii.gz
# processing image 339, sub-CC00526XX15_3.nii.gz
# processing image 340, sub-CC00527XX16_3.nii.gz
# processing image 341, sub-CC00528XX17_2.nii.gz
# processing image 342, sub-CC00529AN18_1.nii.gz
# processing image 343, sub-CC00529BN18_2.nii.gz
# processing image 344, sub-CC00530XX11_5.nii.gz
# processing image 345, sub-CC00532XX13_1.nii.gz
# processing image 346, sub-CC00534XX15_1.nii.gz
# processing image 347, sub-CC00536XX17_1.nii.gz
# processing image 348, sub-CC00540XX13_3.nii.gz
# processing image 349, sub-CC00541XX14_1.nii.gz
# processing image 350, sub-CC00542XX15_1.nii.gz
# processing image 351, sub-CC00544XX17_2.nii.gz
# processing image 352, sub-CC00545XX18_3.nii.gz
# processing image 353, sub-CC00546XX19_5.nii.gz
# processing image 354, sub-CC00547XX20_3.nii.gz
# processing image 355, sub-CC00548XX21_1.nii.gz
# processing image 356, sub-CC00549XX22_2.nii.gz
# processing image 357, sub-CC00550XX06_1.nii.gz
# processing image 358, sub-CC00552XX08_2.nii.gz
# processing image 359, sub-CC00553XX09_2.nii.gz
# processing image 360, sub-CC00555XX11_2.nii.gz
# processing image 361, sub-CC00556XX12_3.nii.gz
# processing image 362, sub-CC00558XX14_5.nii.gz
# processing image 363, sub-CC00561XX09_1.nii.gz
# processing image 364, sub-CC00562XX10_5.nii.gz
# processing image 365, sub-CC00563XX11_1.nii.gz
# processing image 366, sub-CC00564XX12_2.nii.gz
# processing image 367, sub-CC00566XX14_1.nii.gz
# processing image 368, sub-CC00568XX16_2.nii.gz
# processing image 369, sub-CC00569XX17_2.nii.gz
# processing image 370, sub-CC00570XX10_2.nii.gz
# processing image 371, sub-CC00571AN11_5.nii.gz
# processing image 372, sub-CC00572BN12_2.nii.gz
# processing image 373, sub-CC00572CN12_5.nii.gz
# processing image 374, sub-CC00576XX16_2.nii.gz
# processing image 375, sub-CC00577XX17_1.nii.gz
# processing image 376, sub-CC00578AN18_1.nii.gz
# processing image 377, sub-CC00580XX12_2.nii.gz
# processing image 378, sub-CC00581XX13_1.nii.gz
# processing image 379, sub-CC00582XX14_4.nii.gz
# processing image 380, sub-CC00583XX15_1.nii.gz
# processing image 381, sub-CC00584XX16_2.nii.gz
# processing image 382, sub-CC00585XX17_3.nii.gz
# processing image 383, sub-CC00586XX18_1.nii.gz
# processing image 384, sub-CC00587XX19_3.nii.gz
# processing image 385, sub-CC00588XX20_1.nii.gz
# processing image 386, sub-CC00589XX21_1.nii.gz
# processing image 387, sub-CC00590XX14_2.nii.gz
# processing image 388, sub-CC00592XX16_1.nii.gz
# processing image 389, sub-CC00593XX17_1.nii.gz
# processing image 390, sub-CC00594XX18_1.nii.gz
# processing image 391, sub-CC00595XX19_3.nii.gz
# processing image 392, sub-CC00596XX20_1.nii.gz
# processing image 393, sub-CC00597XX21_2.nii.gz
# processing image 394, sub-CC00600XX06_5.nii.gz
# processing image 395, sub-CC00607XX13_1.nii.gz
# processing image 396, sub-CC00613XX11_3.nii.gz
# processing image 397, sub-CC00616XX14_1.nii.gz
# processing image 398, sub-CC00617XX15_2.nii.gz
# processing image 399, sub-CC00618XX16_2.nii.gz
# processing image 400, sub-CC00620XX10_1.nii.gz
# processing image 401, sub-CC00621XX11_3.nii.gz
# processing image 402, sub-CC00622XX12_2.nii.gz
# processing image 403, sub-CC00627XX17_3.nii.gz
# processing image 404, sub-CC00628XX18_2.nii.gz
# processing image 405, sub-CC00629XX19_5.nii.gz
# processing image 406, sub-CC00630XX12_1.nii.gz
# processing image 407, sub-CC00632XX14_2.nii.gz
# processing image 408, sub-CC00639XX21_2.nii.gz
# processing image 409, sub-CC00647XX21_1.nii.gz
# processing image 410, sub-CC00648XX22_2.nii.gz
# processing image 411, sub-CC00649XX23_2.nii.gz
# processing image 412, sub-CC00650XX07_2.nii.gz
# processing image 413, sub-CC00652XX09_2.nii.gz
# processing image 414, sub-CC00653XX10_1.nii.gz
# processing image 415, sub-CC00654XX11_1.nii.gz
# processing image 416, sub-CC00656XX13_1.nii.gz
# processing image 417, sub-CC00657XX14_3.nii.gz
# processing image 418, sub-CC00661XX10_3.nii.gz
# processing image 419, sub-CC00664XX13_2.nii.gz
# processing image 420, sub-CC00667XX16_2.nii.gz
# processing image 421, sub-CC00669XX18_1.nii.gz
# processing image 422, sub-CC00670XX11_1.nii.gz
# processing image 423, sub-CC00671XX12_2.nii.gz
# processing image 424, sub-CC00672AN13_1.nii.gz
# processing image 425, sub-CC00672BN13_1.nii.gz
# processing image 426, sub-CC00675XX16_3.nii.gz
# processing image 427, sub-CC00685XX18_1.nii.gz
# processing image 428, sub-CC00686XX19_3.nii.gz
# processing image 429, sub-CC00687XX20_2.nii.gz
# processing image 430, sub-CC00688XX21_5.nii.gz
# processing image 431, sub-CC00689XX22_5.nii.gz
# processing image 432, sub-CC00692XX17_1.nii.gz
# processing image 433, sub-CC00693XX18_1.nii.gz
# processing image 434, sub-CC00695XX20_3.nii.gz
# processing image 435, sub-CC00702AN09_3.nii.gz
# processing image 436, sub-CC00703XX10_3.nii.gz
# processing image 437, sub-CC00705XX12_1.nii.gz
# processing image 438, sub-CC00712XX11_1.nii.gz
# processing image 439, sub-CC00718XX17_3.nii.gz
# processing image 440, sub-CC00719XX18_2.nii.gz
# processing image 441, sub-CC00720XX11_1.nii.gz
# processing image 442, sub-CC00723XX14_5.nii.gz
# processing image 443, sub-CC00731XX14_1.nii.gz
# processing image 444, sub-CC00734XX17_1.nii.gz
# processing image 445, sub-CC00735XX18_1.nii.gz
# processing image 446, sub-CC00740XX15_2.nii.gz
# processing image 447, sub-CC00744XX19_3.nii.gz
# processing image 448, sub-CC00747XX22_2.nii.gz
# processing image 449, sub-CC00753XX11_1.nii.gz
# processing image 450, sub-CC00754AN12_1.nii.gz
# processing image 451, sub-CC00754BN12_1.nii.gz
# processing image 452, sub-CC00757XX15_1.nii.gz
# processing image 453, sub-CC00760XX10_2.nii.gz
# processing image 454, sub-CC00764AN14_1.nii.gz
# processing image 455, sub-CC00764BN14_1.nii.gz
# processing image 456, sub-CC00765XX15_2.nii.gz
# processing image 457, sub-CC00766XX16_3.nii.gz
# processing image 458, sub-CC00768XX18_1.nii.gz
# processing image 459, sub-CC00770XX12_2.nii.gz
# processing image 460, sub-CC00771XX13_2.nii.gz
# processing image 461, sub-CC00777XX19_1.nii.gz
# processing image 462, sub-CC00785XX19_5.nii.gz
# processing image 463, sub-CC00787XX21_5.nii.gz
# processing image 464, sub-CC00788XX22_1.nii.gz
# processing image 465, sub-CC00789XX23_2.nii.gz
# processing image 466, sub-CC00791XX17_1.nii.gz
# processing image 467, sub-CC00792XX18_1.nii.gz
# processing image 468, sub-CC00793XX19_3.nii.gz
# processing image 469, sub-CC00797XX23_3.nii.gz
# processing image 470, sub-CC00798XX24_1.nii.gz
# processing image 471, sub-CC00799XX25_2.nii.gz
# processing image 472, sub-CC00801XX09_1.nii.gz
# processing image 473, sub-CC00804XX12_3.nii.gz
# processing image 474, sub-CC00805XX13_3.nii.gz
# processing image 475, sub-CC00810XX10_1.nii.gz
# processing image 476, sub-CC00815XX15_1.nii.gz
# processing image 477, sub-CC00818XX18_1.nii.gz
# processing image 478, sub-CC00822XX14_1.nii.gz
# processing image 479, sub-CC00823XX15_1.nii.gz
# processing image 480, sub-CC00824XX16_2.nii.gz
# processing image 481, sub-CC00829XX21_3.nii.gz
# processing image 482, sub-CC00830XX14_1.nii.gz
# processing image 483, sub-CC00833XX17_2.nii.gz
# processing image 484, sub-CC00838XX22_3.nii.gz
# processing image 485, sub-CC00839XX23_1.nii.gz
# processing image 486, sub-CC00840XX16_2.nii.gz
# processing image 487, sub-CC00843XX19_1.nii.gz
# processing image 488, sub-CC00845AN21_1.nii.gz
# processing image 489, sub-CC00845BN21_1.nii.gz
# processing image 490, sub-CC00846XX22_1.nii.gz
# processing image 491, sub-CC00847XX23_2.nii.gz
# processing image 492, sub-CC00850XX09_1.nii.gz
# processing image 493, sub-CC00851XX10_1.nii.gz
# processing image 494, sub-CC00852XX11_1.nii.gz
# processing image 495, sub-CC00853XX12_5.nii.gz
# processing image 496, sub-CC00854XX13_1.nii.gz
# processing image 497, sub-CC00855XX14_1.nii.gz
# processing image 498, sub-CC00858XX17_1.nii.gz
# processing image 499, sub-CC00860XX11_1.nii.gz
# processing image 500, sub-CC00863XX14_1.nii.gz
# processing image 501, sub-CC00871XX14_2.nii.gz
# processing image 502, sub-CC00879XX22_1.nii.gz
# processing image 503, sub-CC00889BN24_1.nii.gz
# processing image 504, sub-CC00907XX16_1.nii.gz
# CPU times: user 9h 49min 4s, sys: 17min 1s, total: 10h 6min 5s
# Wall time: 1h 19min 13s

# %% [markdown]
# ### Histogram Match CHM Data

# %%
# %%time

chm_normal = []
chm_abnormal = []
chm_death = []

for file in os.listdir(chm_registered):
    file_path = os.path.join(chm_registered, file)
    img = ants.image_read(file_path)
    
    img = img.numpy()
    
    img_norm = hist_match(img, uniform)
    
    img_norm = np.rot90(np.rot90(img_norm))
    
    if file.startswith('normal'):
        chm_normal.append(img_norm)
    elif file.startswith('abnormal'):
        chm_abnormal.append(img_norm)
    elif file.startswith('death'):
        chm_death.append(img_norm)

chm_normal = np.array(chm_normal)
chm_abnormal = np.array(chm_abnormal)
chm_death = np.array(chm_death)

np.save(os.path.join(chm_norm, 'chm_normal.npy'), chm_normal)
np.save(os.path.join(chm_norm, 'chm_abnormal.npy'), chm_abnormal)
np.save(os.path.join(chm_norm, 'chm_death.npy'), chm_death)
# Out:
# CPU times: user 4.18 s, sys: 203 ms, total: 4.39 s
# Wall time: 5.07 s

# %% [markdown]
# ### Histogram Match dHCP Data

# %%
# %%time

dhcp_level1 = []
dhcp_level5 = []

counter = 0

for file in os.listdir(dhcp_registered):
    file_path = os.path.join(dhcp_registered, file)
    
    file_level = file[:-7][-1]
    
    if file_level in ['1', '5']:
        img = ants.image_read(file_path)

        img = img.numpy()

        img_norm = hist_match(img, uniform)
    
        if file_level == '1':
            dhcp_level1.append(img_norm)
        elif file_level == '5':
            dhcp_level5.append(img_norm)

dhcp_level1 = np.array(dhcp_level1)
dhcp_level5 = np.array(dhcp_level5)

np.save(os.path.join(dhcp_norm, 'dhcp_level1.npy'), dhcp_level1)
np.save(os.path.join(dhcp_norm, 'dhcp_level5.npy'), dhcp_level5)
# Out:
# CPU times: user 9min 43s, sys: 28.8 s, total: 10min 12s
# Wall time: 11min 32s

# %% [markdown]
# ## dHCP Only

# %% [markdown]
# ### Clean dHCP Data

# %%
# %%time

samples = []

counter = 0
x, y, z = (256, 256, 256)

file_list = os.listdir(dhcp_stripped)
file_list = sorted(file_list)

counter = 0
for file in file_list:
    print(f"processing image {counter}, {file}")
    file_path = os.path.join(dhcp_stripped, file)
    img = ants.image_read(file_path)    
    img = ants.n3_bias_field_correction(img)
    img = ants.resample_image(img, (x, y, z), True, 1)
    if counter == 0:
        ants.image_write(img, os.path.join(dhcp_self_registered, file))
        ref_img = img
    else:
        img = ants.registration(fixed=ref_img, moving=img, type_of_transform='AffineFast')
        ants.image_write(img['warpedmovout'], os.path.join(dhcp_self_registered, file))
    counter += 1
# Out:
# processing image 0, sub-CC00058XX09_1.nii.gz
# processing image 1, sub-CC00060XX03_2.nii.gz
# processing image 2, sub-CC00062XX05_1.nii.gz
# processing image 3, sub-CC00063AN06_1.nii.gz
# processing image 4, sub-CC00065XX08_2.nii.gz
# processing image 5, sub-CC00066XX09_4.nii.gz
# processing image 6, sub-CC00067XX10_1.nii.gz
# processing image 7, sub-CC00068XX11_1.nii.gz
# processing image 8, sub-CC00069XX12_2.nii.gz
# processing image 9, sub-CC00070XX05_3.nii.gz
# processing image 10, sub-CC00071XX06_1.nii.gz
# processing image 11, sub-CC00072XX07_2.nii.gz
# processing image 12, sub-CC00073XX08_1.nii.gz
# processing image 13, sub-CC00074XX09_1.nii.gz
# processing image 14, sub-CC00075XX10_1.nii.gz
# processing image 15, sub-CC00078XX13_2.nii.gz
# processing image 16, sub-CC00079XX14_1.nii.gz
# processing image 17, sub-CC00080XX07_1.nii.gz
# processing image 18, sub-CC00082XX09_1.nii.gz
# processing image 19, sub-CC00083XX10_1.nii.gz
# processing image 20, sub-CC00084XX11_1.nii.gz
# processing image 21, sub-CC00086XX13_2.nii.gz
# processing image 22, sub-CC00087AN14_5.nii.gz
# processing image 23, sub-CC00087BN14_2.nii.gz
# processing image 24, sub-CC00088XX15_1.nii.gz
# processing image 25, sub-CC00089XX16_1.nii.gz
# processing image 26, sub-CC00091XX10_2.nii.gz
# processing image 27, sub-CC00094AN13_2.nii.gz
# processing image 28, sub-CC00094BN13_2.nii.gz
# processing image 29, sub-CC00096XX15_1.nii.gz
# processing image 30, sub-CC00097XX16_1.nii.gz
# processing image 31, sub-CC00098BN17_1.nii.gz
# processing image 32, sub-CC00099AN18_Q.nii.gz
# processing image 33, sub-CC00099BN18_1.nii.gz
# processing image 34, sub-CC00100XX01_1.nii.gz
# processing image 35, sub-CC00101XX02_1.nii.gz
# processing image 36, sub-CC00102XX03_1.nii.gz
# processing image 37, sub-CC00103XX04_5.nii.gz
# processing image 38, sub-CC00104XX05_1.nii.gz
# processing image 39, sub-CC00106XX07_1.nii.gz
# processing image 40, sub-CC00107XX08_1.nii.gz
# processing image 41, sub-CC00108XX09_1.nii.gz
# processing image 42, sub-CC00109XX10_Q.nii.gz
# processing image 43, sub-CC00110XX03_1.nii.gz
# processing image 44, sub-CC00111XX04_2.nii.gz
# processing image 45, sub-CC00113XX06_1.nii.gz
# processing image 46, sub-CC00114XX07_2.nii.gz
# processing image 47, sub-CC00115XX08_2.nii.gz
# processing image 48, sub-CC00116XX09_3.nii.gz
# processing image 49, sub-CC00117XX10_1.nii.gz
# processing image 50, sub-CC00118XX11_1.nii.gz
# processing image 51, sub-CC00119XX12_2.nii.gz
# processing image 52, sub-CC00120XX05_1.nii.gz
# processing image 53, sub-CC00121XX06_4.nii.gz
# processing image 54, sub-CC00122XX07_1.nii.gz
# processing image 55, sub-CC00124XX09_1.nii.gz
# processing image 56, sub-CC00126XX11_1.nii.gz
# processing image 57, sub-CC00127XX12_1.nii.gz
# processing image 58, sub-CC00129AN14_1.nii.gz
# processing image 59, sub-CC00129BN14_3.nii.gz
# processing image 60, sub-CC00130XX07_3.nii.gz
# processing image 61, sub-CC00131XX08_1.nii.gz
# processing image 62, sub-CC00132XX09_1.nii.gz
# processing image 63, sub-CC00134XX11_1.nii.gz
# processing image 64, sub-CC00135AN12_3.nii.gz
# processing image 65, sub-CC00135BN12_3.nii.gz
# processing image 66, sub-CC00136AN13_1.nii.gz
# processing image 67, sub-CC00136BN13_1.nii.gz
# processing image 68, sub-CC00138XX15_1.nii.gz
# processing image 69, sub-CC00143AN12_1.nii.gz
# processing image 70, sub-CC00143BN12_2.nii.gz
# processing image 71, sub-CC00144XX13_Q3.nii.gz
# processing image 72, sub-CC00145XX14_1.nii.gz
# processing image 73, sub-CC00146XX15_1.nii.gz
# processing image 74, sub-CC00147XX16_1.nii.gz
# processing image 75, sub-CC00149XX18_1.nii.gz
# processing image 76, sub-CC00150AN02_1.nii.gz
# processing image 77, sub-CC00150BN02_1.nii.gz
# processing image 78, sub-CC00152AN04_4.nii.gz
# processing image 79, sub-CC00153XX05_1.nii.gz
# processing image 80, sub-CC00154XX06_2.nii.gz
# processing image 81, sub-CC00156XX08_2.nii.gz
# processing image 82, sub-CC00157XX09_1.nii.gz
# processing image 83, sub-CC00158XX10_2.nii.gz
# processing image 84, sub-CC00160XX04_1.nii.gz
# processing image 85, sub-CC00161XX05_1.nii.gz
# processing image 86, sub-CC00162XX06_1.nii.gz
# processing image 87, sub-CC00163XX07_1.nii.gz
# processing image 88, sub-CC00164XX08_1.nii.gz
# processing image 89, sub-CC00165XX09_1.nii.gz
# processing image 90, sub-CC00167XX11_2.nii.gz
# processing image 91, sub-CC00168XX12_1.nii.gz
# processing image 92, sub-CC00170XX06_1.nii.gz
# processing image 93, sub-CC00171XX07_2.nii.gz
# processing image 94, sub-CC00172AN08_1.nii.gz
# processing image 95, sub-CC00172BN08_1.nii.gz
# processing image 96, sub-CC00174XX10_2.nii.gz
# processing image 97, sub-CC00176XX12_1.nii.gz
# processing image 98, sub-CC00177XX13_1.nii.gz
# processing image 99, sub-CC00178XX14_1.nii.gz
# processing image 100, sub-CC00179XX15_1.nii.gz
# processing image 101, sub-CC00180XX08_1.nii.gz
# processing image 102, sub-CC00181XX09_1.nii.gz
# processing image 103, sub-CC00182XX10_1.nii.gz
# processing image 104, sub-CC00183XX11_1.nii.gz
# processing image 105, sub-CC00184XX12_1.nii.gz
# processing image 106, sub-CC00185XX13_2.nii.gz
# processing image 107, sub-CC00186AN14_3.nii.gz
# processing image 108, sub-CC00186BN14_3.nii.gz
# processing image 109, sub-CC00187XX15_1.nii.gz
# processing image 110, sub-CC00188XX16_1.nii.gz
# processing image 111, sub-CC00189XX17_1.nii.gz
# processing image 112, sub-CC00191XX11_2.nii.gz
# processing image 113, sub-CC00192AN12_3.nii.gz
# processing image 114, sub-CC00193XX13_1.nii.gz
# processing image 115, sub-CC00194XX14_5.nii.gz
# processing image 116, sub-CC00195XX15_1.nii.gz
# processing image 117, sub-CC00196XX16_1.nii.gz
# processing image 118, sub-CC00197XX17_3.nii.gz
# processing image 119, sub-CC00198XX18_1.nii.gz
# processing image 120, sub-CC00199XX19_3.nii.gz
# processing image 121, sub-CC00200XX02_1.nii.gz
# processing image 122, sub-CC00201XX03_1.nii.gz
# processing image 123, sub-CC00202XX04_2.nii.gz
# processing image 124, sub-CC00203XX05_2.nii.gz
# processing image 125, sub-CC00204XX06_1.nii.gz
# processing image 126, sub-CC00205XX07_1.nii.gz
# processing image 127, sub-CC00206XX08_1.nii.gz
# processing image 128, sub-CC00207XX09_1.nii.gz
# processing image 129, sub-CC00209XX11_1.nii.gz
# processing image 130, sub-CC00216AN10_2.nii.gz
# processing image 131, sub-CC00216BN10_2.nii.gz
# processing image 132, sub-CC00217XX11_1.nii.gz
# processing image 133, sub-CC00218AN12_5.nii.gz
# processing image 134, sub-CC00218BN12_1.nii.gz
# processing image 135, sub-CC00219XX13_3.nii.gz
# processing image 136, sub-CC00221XX07_4.nii.gz
# processing image 137, sub-CC00223XX09_1.nii.gz
# processing image 138, sub-CC00226XX12_2.nii.gz
# processing image 139, sub-CC00227XX13_1.nii.gz
# processing image 140, sub-CC00231XX09_5.nii.gz
# processing image 141, sub-CC00232XX10_1.nii.gz
# processing image 142, sub-CC00233XX11_1.nii.gz
# processing image 143, sub-CC00236XX14_2.nii.gz
# processing image 144, sub-CC00237XX15_2.nii.gz
# processing image 145, sub-CC00238AN16_2.nii.gz
# processing image 146, sub-CC00238BN16_1.nii.gz
# processing image 147, sub-CC00244XX14_3.nii.gz
# processing image 148, sub-CC00245AN15_1.nii.gz
# processing image 149, sub-CC00245BN15_1.nii.gz
# processing image 150, sub-CC00247XX17_1.nii.gz
# processing image 151, sub-CC00248XX18_5.nii.gz
# processing image 152, sub-CC00250XX03_1.nii.gz
# processing image 153, sub-CC00251XX04_1.nii.gz
# processing image 154, sub-CC00252XX05_2.nii.gz
# processing image 155, sub-CC00254XX07_1.nii.gz
# processing image 156, sub-CC00255XX08_5.nii.gz
# processing image 157, sub-CC00257XX10_1.nii.gz
# processing image 158, sub-CC00258XX11_1.nii.gz
# processing image 159, sub-CC00260XX05_2.nii.gz
# processing image 160, sub-CC00261XX06_1.nii.gz
# processing image 161, sub-CC00265XX10_2.nii.gz
# processing image 162, sub-CC00267XX12_2.nii.gz
# processing image 163, sub-CC00268XX13_1.nii.gz
# processing image 164, sub-CC00269XX14_2.nii.gz
# processing image 165, sub-CC00270XX07_3.nii.gz
# processing image 166, sub-CC00271XX08_2.nii.gz
# processing image 167, sub-CC00272XX09_1.nii.gz
# processing image 168, sub-CC00275XX12_1.nii.gz
# processing image 169, sub-CC00281AN10_1.nii.gz
# processing image 170, sub-CC00284AN13_2.nii.gz
# processing image 171, sub-CC00284BN13_2.nii.gz
# processing image 172, sub-CC00286XX15_1.nii.gz
# processing image 173, sub-CC00289XX18_2.nii.gz
# processing image 174, sub-CC00290XX11_1.nii.gz
# processing image 175, sub-CC00292XX13_2.nii.gz
# processing image 176, sub-CC00293AN14_2.nii.gz
# processing image 177, sub-CC00293BN14_2.nii.gz
# processing image 178, sub-CC00295XX16_1.nii.gz
# processing image 179, sub-CC00298XX19_2.nii.gz
# processing image 180, sub-CC00299XX20_1.nii.gz
# processing image 181, sub-CC00300XX03_1.nii.gz
# processing image 182, sub-CC00301XX04_5.nii.gz
# processing image 183, sub-CC00302XX05_1.nii.gz
# processing image 184, sub-CC00303XX06_2.nii.gz
# processing image 185, sub-CC00304XX07_1.nii.gz
# processing image 186, sub-CC00305XX08_2.nii.gz
# processing image 187, sub-CC00306XX09_2.nii.gz
# processing image 188, sub-CC00307XX10_2.nii.gz
# processing image 189, sub-CC00308XX11_1.nii.gz
# processing image 190, sub-CC00309BN12_2.nii.gz
# processing image 191, sub-CC00313XX08_1.nii.gz
# processing image 192, sub-CC00314XX09_2.nii.gz
# processing image 193, sub-CC00316XX11_2.nii.gz
# processing image 194, sub-CC00319XX14_1.nii.gz
# processing image 195, sub-CC00320XX07_2.nii.gz
# processing image 196, sub-CC00324XX11_2.nii.gz
# processing image 197, sub-CC00326XX13_1.nii.gz
# processing image 198, sub-CC00329XX16_2.nii.gz
# processing image 199, sub-CC00330XX09_1.nii.gz
# processing image 200, sub-CC00332XX11_1.nii.gz
# processing image 201, sub-CC00334XX13_1.nii.gz
# processing image 202, sub-CC00335XX14_2.nii.gz
# processing image 203, sub-CC00336XX15_2.nii.gz
# processing image 204, sub-CC00337XX16_1.nii.gz
# processing image 205, sub-CC00338AN17_1.nii.gz
# processing image 206, sub-CC00338BN17_1.nii.gz
# processing image 207, sub-CC00339XX18_2.nii.gz
# processing image 208, sub-CC00340XX11_2.nii.gz
# processing image 209, sub-CC00341XX12_3.nii.gz
# processing image 210, sub-CC00342XX13_1.nii.gz
# processing image 211, sub-CC00343XX14_2.nii.gz
# processing image 212, sub-CC00344XX15_1.nii.gz
# processing image 213, sub-CC00346XX17_1.nii.gz
# processing image 214, sub-CC00347XX18_2.nii.gz
# processing image 215, sub-CC00348XX19_1.nii.gz
# processing image 216, sub-CC00349XX20_2.nii.gz
# processing image 217, sub-CC00350XX04_3.nii.gz
# processing image 218, sub-CC00351XX05_1.nii.gz
# processing image 219, sub-CC00352XX06_2.nii.gz
# processing image 220, sub-CC00354XX08_1.nii.gz
# processing image 221, sub-CC00355XX09_2.nii.gz
# processing image 222, sub-CC00356XX10_2.nii.gz
# processing image 223, sub-CC00357XX11_1.nii.gz
# processing image 224, sub-CC00361XX07_1.nii.gz
# processing image 225, sub-CC00362XX08_2.nii.gz
# processing image 226, sub-CC00363XX09_1.nii.gz
# processing image 227, sub-CC00364XX10_2.nii.gz
# processing image 228, sub-CC00366XX12_3.nii.gz
# processing image 229, sub-CC00367XX13_1.nii.gz
# processing image 230, sub-CC00368XX14_1.nii.gz
# processing image 231, sub-CC00370XX08_2.nii.gz
# processing image 232, sub-CC00371XX09_2.nii.gz
# processing image 233, sub-CC00376XX14_1.nii.gz
# processing image 234, sub-CC00377XX15_2.nii.gz
# processing image 235, sub-CC00378XX16_1.nii.gz
# processing image 236, sub-CC00379XX17_4.nii.gz
# processing image 237, sub-CC00380XX10_2.nii.gz
# processing image 238, sub-CC00381XX11_1.nii.gz
# processing image 239, sub-CC00382XX12_1.nii.gz
# processing image 240, sub-CC00383XX13_1.nii.gz
# processing image 241, sub-CC00384XX14_5.nii.gz
# processing image 242, sub-CC00385XX15_1.nii.gz
# processing image 243, sub-CC00388XX18_2.nii.gz
# processing image 244, sub-CC00389XX19_2.nii.gz
# processing image 245, sub-CC00395XX17_5.nii.gz
# processing image 246, sub-CC00397XX19_4.nii.gz
# processing image 247, sub-CC00398XX20_4.nii.gz
# processing image 248, sub-CC00399XX21_3.nii.gz
# processing image 249, sub-CC00400XX04_2.nii.gz
# processing image 250, sub-CC00402XX06_1.nii.gz
# processing image 251, sub-CC00403XX07_2.nii.gz
# processing image 252, sub-CC00405XX09_3.nii.gz
# processing image 253, sub-CC00406XX10_3.nii.gz
# processing image 254, sub-CC00407AN11_3.nii.gz
# processing image 255, sub-CC00407BN11_1.nii.gz
# processing image 256, sub-CC00408XX12_2.nii.gz
# processing image 257, sub-CC00409XX13_2.nii.gz
# processing image 258, sub-CC00410XX06_1.nii.gz
# processing image 259, sub-CC00411XX07_3.nii.gz
# processing image 260, sub-CC00412XX08_2.nii.gz
# processing image 261, sub-CC00413XX09_1.nii.gz
# processing image 262, sub-CC00414XX10_5.nii.gz
# processing image 263, sub-CC00415XX11_1.nii.gz
# processing image 264, sub-CC00416XX12_5.nii.gz
# processing image 265, sub-CC00417XX13_3.nii.gz
# processing image 266, sub-CC00418AN14_3.nii.gz
# processing image 267, sub-CC00418BN14_5.nii.gz
# processing image 268, sub-CC00421AN09_1.nii.gz
# processing image 269, sub-CC00421BN09_1.nii.gz
# processing image 270, sub-CC00422XX10_3.nii.gz
# processing image 271, sub-CC00423XX11_5.nii.gz
# processing image 272, sub-CC00424XX12_2.nii.gz
# processing image 273, sub-CC00428XX16_2.nii.gz
# processing image 274, sub-CC00429XX17_1.nii.gz
# processing image 275, sub-CC00430XX10_1.nii.gz
# processing image 276, sub-CC00431XX11_2.nii.gz
# processing image 277, sub-CC00433XX13_1.nii.gz
# processing image 278, sub-CC00434AN14_3.nii.gz
# processing image 279, sub-CC00438XX18_1.nii.gz
# processing image 280, sub-CC00439XX19_2.nii.gz
# processing image 281, sub-CC00440XX12_2.nii.gz
# processing image 282, sub-CC00441XX13_2.nii.gz
# processing image 283, sub-CC00442XX14_2.nii.gz
# processing image 284, sub-CC00443XX15_2.nii.gz
# processing image 285, sub-CC00444XX16_2.nii.gz
# processing image 286, sub-CC00445XX17_2.nii.gz
# processing image 287, sub-CC00446XX18_2.nii.gz
# processing image 288, sub-CC00447XX19_2.nii.gz
# processing image 289, sub-CC00448XX20_2.nii.gz
# processing image 290, sub-CC00450XX05_2.nii.gz
# processing image 291, sub-CC00451XX06_2.nii.gz
# processing image 292, sub-CC00453XX08_1.nii.gz
# processing image 293, sub-CC00454XX09_5.nii.gz
# processing image 294, sub-CC00455XX10_2.nii.gz
# processing image 295, sub-CC00456XX11_5.nii.gz
# processing image 296, sub-CC00457XX12_2.nii.gz
# processing image 297, sub-CC00458XX13_1.nii.gz
# processing image 298, sub-CC00461XX08_2.nii.gz
# processing image 299, sub-CC00465XX12_2.nii.gz
# processing image 300, sub-CC00466AN13_2.nii.gz
# processing image 301, sub-CC00466BN13_2.nii.gz
# processing image 302, sub-CC00467XX14_2.nii.gz
# processing image 303, sub-CC00468XX15_1.nii.gz
# processing image 304, sub-CC00469XX16_2.nii.gz
# processing image 305, sub-CC00470XX09_2.nii.gz
# processing image 306, sub-CC00472XX11_2.nii.gz
# processing image 307, sub-CC00473XX12_1.nii.gz
# processing image 308, sub-CC00474XX13_2.nii.gz
# processing image 309, sub-CC00476XX15_1.nii.gz
# processing image 310, sub-CC00478XX17_2.nii.gz
# processing image 311, sub-CC00479XX18_1.nii.gz
# processing image 312, sub-CC00480XX11_1.nii.gz
# processing image 313, sub-CC00481XX12_2.nii.gz
# processing image 314, sub-CC00482XX13_2.nii.gz
# processing image 315, sub-CC00483XX14_2.nii.gz
# processing image 316, sub-CC00484XX15_1.nii.gz
# processing image 317, sub-CC00486XX17_2.nii.gz
# processing image 318, sub-CC00489XX20_3.nii.gz
# processing image 319, sub-CC00492AN15_1.nii.gz
# processing image 320, sub-CC00492BN15_2.nii.gz
# processing image 321, sub-CC00497XX20_1.nii.gz
# processing image 322, sub-CC00498XX21_2.nii.gz
# processing image 323, sub-CC00499XX22_2.nii.gz
# processing image 324, sub-CC00500XX05_1.nii.gz
# processing image 325, sub-CC00501XX06_1.nii.gz
# processing image 326, sub-CC00502XX07_2.nii.gz
# processing image 327, sub-CC00504XX09_1.nii.gz
# processing image 328, sub-CC00505XX10_2.nii.gz
# processing image 329, sub-CC00507XX12_1.nii.gz
# processing image 330, sub-CC00508XX13_2.nii.gz
# processing image 331, sub-CC00512XX09_2.nii.gz
# processing image 332, sub-CC00513XX10_5.nii.gz
# processing image 333, sub-CC00514XX11_1.nii.gz
# processing image 334, sub-CC00516XX13_2.nii.gz
# processing image 335, sub-CC00517XX14_3.nii.gz
# processing image 336, sub-CC00518XX15_3.nii.gz
# processing image 337, sub-CC00520XX09_2.nii.gz
# processing image 338, sub-CC00525XX14_2.nii.gz
# processing image 339, sub-CC00526XX15_3.nii.gz
# processing image 340, sub-CC00527XX16_3.nii.gz
# processing image 341, sub-CC00528XX17_2.nii.gz
# processing image 342, sub-CC00529AN18_1.nii.gz
# processing image 343, sub-CC00529BN18_2.nii.gz
# processing image 344, sub-CC00530XX11_5.nii.gz
# processing image 345, sub-CC00532XX13_1.nii.gz
# processing image 346, sub-CC00534XX15_1.nii.gz
# processing image 347, sub-CC00536XX17_1.nii.gz
# processing image 348, sub-CC00540XX13_3.nii.gz
# processing image 349, sub-CC00541XX14_1.nii.gz
# processing image 350, sub-CC00542XX15_1.nii.gz
# processing image 351, sub-CC00544XX17_2.nii.gz
# processing image 352, sub-CC00545XX18_3.nii.gz
# processing image 353, sub-CC00546XX19_5.nii.gz
# processing image 354, sub-CC00547XX20_3.nii.gz
# processing image 355, sub-CC00548XX21_1.nii.gz
# processing image 356, sub-CC00549XX22_2.nii.gz
# processing image 357, sub-CC00550XX06_1.nii.gz
# processing image 358, sub-CC00552XX08_2.nii.gz
# processing image 359, sub-CC00553XX09_2.nii.gz
# processing image 360, sub-CC00555XX11_2.nii.gz
# processing image 361, sub-CC00556XX12_3.nii.gz
# processing image 362, sub-CC00558XX14_5.nii.gz
# processing image 363, sub-CC00561XX09_1.nii.gz
# processing image 364, sub-CC00562XX10_5.nii.gz
# processing image 365, sub-CC00563XX11_1.nii.gz
# processing image 366, sub-CC00564XX12_2.nii.gz
# processing image 367, sub-CC00566XX14_1.nii.gz
# processing image 368, sub-CC00568XX16_2.nii.gz
# processing image 369, sub-CC00569XX17_2.nii.gz
# processing image 370, sub-CC00570XX10_2.nii.gz
# processing image 371, sub-CC00571AN11_5.nii.gz
# processing image 372, sub-CC00572BN12_2.nii.gz
# processing image 373, sub-CC00572CN12_5.nii.gz
# processing image 374, sub-CC00576XX16_2.nii.gz
# processing image 375, sub-CC00577XX17_1.nii.gz
# processing image 376, sub-CC00578AN18_1.nii.gz
# processing image 377, sub-CC00580XX12_2.nii.gz
# processing image 378, sub-CC00581XX13_1.nii.gz
# processing image 379, sub-CC00582XX14_4.nii.gz
# processing image 380, sub-CC00583XX15_1.nii.gz
# processing image 381, sub-CC00584XX16_2.nii.gz
# processing image 382, sub-CC00585XX17_3.nii.gz
# processing image 383, sub-CC00586XX18_1.nii.gz
# processing image 384, sub-CC00587XX19_3.nii.gz
# processing image 385, sub-CC00588XX20_1.nii.gz
# processing image 386, sub-CC00589XX21_1.nii.gz
# processing image 387, sub-CC00590XX14_2.nii.gz
# processing image 388, sub-CC00592XX16_1.nii.gz
# processing image 389, sub-CC00593XX17_1.nii.gz
# processing image 390, sub-CC00594XX18_1.nii.gz
# processing image 391, sub-CC00595XX19_3.nii.gz
# processing image 392, sub-CC00596XX20_1.nii.gz
# processing image 393, sub-CC00597XX21_2.nii.gz
# processing image 394, sub-CC00600XX06_5.nii.gz
# processing image 395, sub-CC00607XX13_1.nii.gz
# processing image 396, sub-CC00613XX11_3.nii.gz
# processing image 397, sub-CC00616XX14_1.nii.gz
# processing image 398, sub-CC00617XX15_2.nii.gz
# processing image 399, sub-CC00618XX16_2.nii.gz
# processing image 400, sub-CC00620XX10_1.nii.gz
# processing image 401, sub-CC00621XX11_3.nii.gz
# processing image 402, sub-CC00622XX12_2.nii.gz
# processing image 403, sub-CC00627XX17_3.nii.gz
# processing image 404, sub-CC00628XX18_2.nii.gz
# processing image 405, sub-CC00629XX19_5.nii.gz
# processing image 406, sub-CC00630XX12_1.nii.gz
# processing image 407, sub-CC00632XX14_2.nii.gz
# processing image 408, sub-CC00639XX21_2.nii.gz
# processing image 409, sub-CC00647XX21_1.nii.gz
# processing image 410, sub-CC00648XX22_2.nii.gz
# processing image 411, sub-CC00649XX23_2.nii.gz
# processing image 412, sub-CC00650XX07_2.nii.gz
# processing image 413, sub-CC00652XX09_2.nii.gz
# processing image 414, sub-CC00653XX10_1.nii.gz
# processing image 415, sub-CC00654XX11_1.nii.gz
# processing image 416, sub-CC00656XX13_1.nii.gz
# processing image 417, sub-CC00657XX14_3.nii.gz
# processing image 418, sub-CC00661XX10_3.nii.gz
# processing image 419, sub-CC00664XX13_2.nii.gz
# processing image 420, sub-CC00667XX16_2.nii.gz
# processing image 421, sub-CC00669XX18_1.nii.gz
# processing image 422, sub-CC00670XX11_1.nii.gz
# processing image 423, sub-CC00671XX12_2.nii.gz
# processing image 424, sub-CC00672AN13_1.nii.gz
# processing image 425, sub-CC00672BN13_1.nii.gz
# processing image 426, sub-CC00675XX16_3.nii.gz
# processing image 427, sub-CC00685XX18_1.nii.gz
# processing image 428, sub-CC00686XX19_3.nii.gz
# processing image 429, sub-CC00687XX20_2.nii.gz
# processing image 430, sub-CC00688XX21_5.nii.gz
# processing image 431, sub-CC00689XX22_5.nii.gz
# processing image 432, sub-CC00692XX17_1.nii.gz
# processing image 433, sub-CC00693XX18_1.nii.gz
# processing image 434, sub-CC00695XX20_3.nii.gz
# processing image 435, sub-CC00702AN09_3.nii.gz
# processing image 436, sub-CC00703XX10_3.nii.gz
# processing image 437, sub-CC00705XX12_1.nii.gz
# processing image 438, sub-CC00712XX11_1.nii.gz
# processing image 439, sub-CC00718XX17_3.nii.gz
# processing image 440, sub-CC00719XX18_2.nii.gz
# processing image 441, sub-CC00720XX11_1.nii.gz
# processing image 442, sub-CC00723XX14_5.nii.gz
# processing image 443, sub-CC00731XX14_1.nii.gz
# processing image 444, sub-CC00734XX17_1.nii.gz
# processing image 445, sub-CC00735XX18_1.nii.gz
# processing image 446, sub-CC00740XX15_2.nii.gz
# processing image 447, sub-CC00744XX19_3.nii.gz
# processing image 448, sub-CC00747XX22_2.nii.gz
# processing image 449, sub-CC00753XX11_1.nii.gz
# processing image 450, sub-CC00754AN12_1.nii.gz
# processing image 451, sub-CC00754BN12_1.nii.gz
# processing image 452, sub-CC00757XX15_1.nii.gz
# processing image 453, sub-CC00760XX10_2.nii.gz
# processing image 454, sub-CC00764AN14_1.nii.gz
# processing image 455, sub-CC00764BN14_1.nii.gz
# processing image 456, sub-CC00765XX15_2.nii.gz
# processing image 457, sub-CC00766XX16_3.nii.gz
# processing image 458, sub-CC00768XX18_1.nii.gz
# processing image 459, sub-CC00770XX12_2.nii.gz
# processing image 460, sub-CC00771XX13_2.nii.gz
# processing image 461, sub-CC00777XX19_1.nii.gz
# processing image 462, sub-CC00785XX19_5.nii.gz
# processing image 463, sub-CC00787XX21_5.nii.gz
# processing image 464, sub-CC00788XX22_1.nii.gz
# processing image 465, sub-CC00789XX23_2.nii.gz
# processing image 466, sub-CC00791XX17_1.nii.gz
# processing image 467, sub-CC00792XX18_1.nii.gz
# processing image 468, sub-CC00793XX19_3.nii.gz
# processing image 469, sub-CC00797XX23_3.nii.gz
# processing image 470, sub-CC00798XX24_1.nii.gz
# processing image 471, sub-CC00799XX25_2.nii.gz
# processing image 472, sub-CC00801XX09_1.nii.gz
# processing image 473, sub-CC00804XX12_3.nii.gz
# processing image 474, sub-CC00805XX13_3.nii.gz
# processing image 475, sub-CC00810XX10_1.nii.gz
# processing image 476, sub-CC00815XX15_1.nii.gz
# processing image 477, sub-CC00818XX18_1.nii.gz
# processing image 478, sub-CC00822XX14_1.nii.gz
# processing image 479, sub-CC00823XX15_1.nii.gz
# processing image 480, sub-CC00824XX16_2.nii.gz
# processing image 481, sub-CC00829XX21_3.nii.gz
# processing image 482, sub-CC00830XX14_1.nii.gz
# processing image 483, sub-CC00833XX17_2.nii.gz
# processing image 484, sub-CC00838XX22_3.nii.gz
# processing image 485, sub-CC00839XX23_1.nii.gz
# processing image 486, sub-CC00840XX16_2.nii.gz
# processing image 487, sub-CC00843XX19_1.nii.gz
# processing image 488, sub-CC00845AN21_1.nii.gz
# processing image 489, sub-CC00845BN21_1.nii.gz
# processing image 490, sub-CC00846XX22_1.nii.gz
# processing image 491, sub-CC00847XX23_2.nii.gz
# processing image 492, sub-CC00850XX09_1.nii.gz
# processing image 493, sub-CC00851XX10_1.nii.gz
# processing image 494, sub-CC00852XX11_1.nii.gz
# processing image 495, sub-CC00853XX12_5.nii.gz
# processing image 496, sub-CC00854XX13_1.nii.gz
# processing image 497, sub-CC00855XX14_1.nii.gz
# processing image 498, sub-CC00858XX17_1.nii.gz
# processing image 499, sub-CC00860XX11_1.nii.gz
# processing image 500, sub-CC00863XX14_1.nii.gz
# processing image 501, sub-CC00871XX14_2.nii.gz
# processing image 502, sub-CC00879XX22_1.nii.gz
# processing image 503, sub-CC00889BN24_1.nii.gz
# processing image 504, sub-CC00907XX16_1.nii.gz
# CPU times: user 7h 29min 54s, sys: 18min 55s, total: 7h 48min 50s
# Wall time: 59min 31s

# %% [markdown]
# ### Histogram Match dHCP Data

# %%
# %%time

dhcp_level1 = []
dhcp_level5 = []

counter = 0

for file in os.listdir(dhcp_self_registered):
    file_path = os.path.join(dhcp_self_registered, file)
    
    file_level = file[:-7][-1]
    
    if file_level in ['1', '5']:
        img = ants.image_read(file_path)

        img = img.numpy()

        img_norm = hist_match(img, uniform)
    
        if file_level == '1':
            dhcp_level1.append(img_norm)
        elif file_level == '5':
            dhcp_level5.append(img_norm)

dhcp_level1 = np.array(dhcp_level1)
dhcp_level5 = np.array(dhcp_level5)

np.save(os.path.join(dhcp_self_norm, 'dhcp_level1.npy'), dhcp_level1)
np.save(os.path.join(dhcp_self_norm, 'dhcp_level5.npy'), dhcp_level5)
# Out:
# CPU times: user 8min 57s, sys: 26.5 s, total: 9min 24s
# Wall time: 10min 10s

# %% [markdown]
# ### dHCP Standardized

# %%
# %%time

dhcp_level1 = []
dhcp_level5 = []

counter = 0

for file in os.listdir(dhcp_self_registered):
    file_path = os.path.join(dhcp_self_registered, file)
    
    file_level = file[:-7][-1]
    
    if file_level in ['1', '5']:
#         print(f"Processing image {counter}")
        img = ants.image_read(file_path)

        img = img.numpy()

        amax = np.amax(img)
        amin = np.amin(img)
        
        img = (img - amin) / (amax - amin)
    
        if file_level == '1':
            dhcp_level1.append(img)
        elif file_level == '5':
            print(file)
            dhcp_level5.append(img)
            
        counter += 1

# dhcp_level1 = np.array(dhcp_level1)
# dhcp_level5 = np.array(dhcp_level5)

# np.save(os.path.join(dhcp_standardized, 'dhcp_level1.npy'), dhcp_level1)
# np.save(os.path.join(dhcp_standardized, 'dhcp_level5.npy'), dhcp_level5)
# Out:
# sub-CC00087AN14_5.nii.gz
# sub-CC00103XX04_5.nii.gz
# sub-CC00194XX14_5.nii.gz
# sub-CC00218AN12_5.nii.gz
# sub-CC00231XX09_5.nii.gz
# sub-CC00248XX18_5.nii.gz
# sub-CC00255XX08_5.nii.gz
# sub-CC00301XX04_5.nii.gz
# CPU times: user 28.8 s, sys: 5.96 s, total: 34.7 s
# Wall time: 35 s
